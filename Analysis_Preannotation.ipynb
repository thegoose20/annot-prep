# %% [markdown]
# # Identifying People in CDCS Metadata Descriptions
# Run named entity recognition (NER) on the metadata descriptions extracted from the CDCS' online archival catalog.
#
# The code in this Jupyter Notebook is part of a PhD project to create a gold standard dataset labeled for gender biased language, on which a classifier can be trained to identify gender bias in archival metadata descriptions.
#
# This project is focused on the English language and archival institutions in the United Kingdom.
#
# * Author: Lucy Havens
# * Date: November 2020 - February 2021
# * Project: PhD Case Study 1
# * Data Provider: [ArchivesSpace](https://archives.collections.ed.ac.uk/), Centre for Research Collections, University of Edinburgh
#
# ***
#
# **Table of Contents**
#
#   [I. Corpus Statistics](#corpus-stats)
#
#   [II. Named Entity Recognition with SpaCy](#ner)
#
#   [III. Checking for Duplicate Descritions](#check-dups)
#
# ***

# %%
import pandas as pd

import nltk
from nltk.tokenize import word_tokenize
from nltk.tokenize import sent_tokenize
# nltk.download('punkt')
from nltk.corpus import PlaintextCorpusReader
# nltk.download('averaged_perceptron_tagger')
from nltk.corpus import stopwords
# nltk.download('stopwords')
from nltk.tag import pos_tag
import string
import csv
import re

import spacy
from spacy import displacy
from collections import Counter
try:
    import en_core_web_sm
except ImportError:
    print("Downlading en_core_web_sm model")
    import sys
    # !{sys.executable} -m spacy download en_core_web_sm
else:
    print("Already have en_core_web_sm")
import en_core_web_sm
nlp = en_core_web_sm.load()
# Out:
# Already have en_core_web_sm

# %% [markdown]
# <a id="corpus-stats"></a>
# ## I. Corpus Statisctics

# %%
descs = PlaintextCorpusReader("lucy_final/", ".+\.txt")

# %%
tokens = descs.words()
print(tokens[0:20])
# Out:
# ['Identifier', ':', 'AA5', 'Title', ':', 'Papers', 'of', 'The', 'Very', 'Rev', 'Prof', 'James', 'Whyte', '(', '1920', '-', '2005', ')', 'Scope', 'and']

# %%
sentences = descs.sents()
print(sentences[0:5])
# Out:
# [['Identifier', ':', 'AA5'], ['Title', ':', 'Papers', 'of', 'The', 'Very', 'Rev', 'Prof', 'James', 'Whyte', '(', '1920', '-', '2005', ')'], ['Scope', 'and', 'Contents', ':', 'Sermons', 'and', 'addresses', ',', '1948', '-', '1996', ';', 'lectures', ',', '1949', '-', '1982', ';', 'class', 'notes', 'and', 'lecture', 'notes', ',', '1949', '-', '1982', ';', 'correspondence', ',', '1988', '-', '1989', 'and', '1964', '-', '1970', ';', 'newspaper', 'cuttings', ',', '1988', '-', '1989', 'and', '1964', '-', '1969', ';', 'publications', 'and', 'articles', ',', '1902', '-', '1970', ';', 'church', 'magazines', ',', '1929', '-', '1993', ';', 'conference', 'papers', ',', '1978', ';', 'moderatorial', 'papers', ',', '1988', '-', '1989', ';', 'University', 'Christian', 'Consultative', 'Group', 'papers', ',', '1970', '-', '1972', ';', 'Church', 'of', 'Scotland', 'and', 'the', 'Congregational', 'Union', 'of', 'Scotland', 'papers', ',', '1959', '-', '1967', ';', 'personal', 'papers', ',', '1848', '-', '1983', ';', 'photographs', '1911', 'and', '1960', '.', 'See', 'also', 'External', 'Documents', '(', 'below', ').'], ['Biographical', '/', 'Historical', ':', 'Professor', 'James', 'Aitken', 'White', 'was', 'a', 'leading', 'Scottish', 'Theologian', 'and', 'Moderator', 'of', 'the', 'General', 'Assembly', 'of', 'the', 'Church', 'of', 'Scotland', '.'], ['He', 'was', 'educated', 'at', 'Daniel', 'Stewart', "'", 's', 'College', 'and', 'the', 'University', 'of', 'Edinburgh', 'where', 'he', 'studied', 'philosophy', 'and', 'divinity', '.']]

# %%
def corpusStatistics(plaintext_corpus_read_lists):
    total_chars = 0
    total_tokens = 0
    total_sents = 0
    total_files = 0
    
    # fileids are the TXT file names in the nls-text-ladiesDebating folder:
    for fileid in plaintext_corpus_read_lists.fileids():
        total_chars += len(plaintext_corpus_read_lists.raw(fileid))
        total_tokens += len(plaintext_corpus_read_lists.words(fileid))
        total_sents += len(plaintext_corpus_read_lists.sents(fileid))
        total_files += 1
    
    print("Total...")
    print("  Characters:", total_chars)
    print("  Tokens:", total_tokens)
    print("  Sentences:", total_sents)
    print("  Files:", total_files)

corpusStatistics(descs)
# Out:
# Total...
#   Characters: 14915776
#   Tokens: 2965456
#   Sentences: 169637
#   Files: 3961

# %%
words = [t for t in tokens if t.isalpha()]
print("Total Words:",len(words))
# Out:
# Total Words: 2150078

# %%
to_exclude = set((stopwords.words("english")) + ["Title", "Identifier", "Scope", 
                "Contents", "Biograhical", "Historical", "Processing", "Information"]
                )
words = [w for w in words if w not in to_exclude]

# %%
print("Total Words Excluding Metadata Field Names:",len(words))
# Out:
# Total Words Excluding Metadata Field Names: 1355667

# %% [markdown]
# <a id="ner"></a>
# ## II. Name Entity Recognition with spaCy
# Run named entity recognition (NER) to estimate the names in the dataset and get a sense for the value in manually labeling names during the annotation process.

# %%
fileids = descs.fileids()

# %%
sentences = []
for fileid in fileids:
    file = descs.raw(fileid)
    sentences += nltk.sent_tokenize(file)

# %%
person_list = []
for s in sentences:
    s_ne = nlp(s)
    for entity in s_ne.ents:
        if entity.label_ == 'PERSON':
            person_list += [entity.text]

# %%
unique_persons = list(set(person_list))
print(len(unique_persons))
# Out:
# 28565

# %%
unique_persons
# Out:
# ['W. Warre Cornish',
#  'George Kennedy',
#  'Triticum',
#  'Honorary D.D.',
#  'Dave',
#  'E. W. Dallas',
#  'John Forestar',
#  'Alexander Smith / David Laing',
#  'David Prowdie',
#  'Lewis R\n\nScope',
#  'Robert Abercrombie',
#  'Völklinger Hütte',
#  'John Kemlok',
#  'B J Bedell, Psychometrika',
#  'William Laidlaw',
#  'Neil Morrison',
#  'Routledge',
#  'Andhra Pradesh',
#  'James Lindsay',
#  'Jake Kugel',
#  'Alexander Honiman',
#  'Fletcher Hayes',
#  'Thomas Forrest',
#  'William Edmondstoune Aytoun',
#  'Alex Forbes Epis',
#  'MS_BOX_17',
#  'Margaret May',
#  'Leeds Co-Op',
#  'George Grove',
#  'Basil Zaharoff',
#  'Nicholson',
#  'Maurice Wilkins',
#  'Michael Ramsay',
#  'Hine',
#  'Walter Brown',
#  'Fitzroy St [',
#  'Nathaniel Wallis',
#  'Removing Ant Heap\n\n',
#  'Rue Saint-Jean',
#  'Housemaid',
#  'Official Transumpt',
#  'Collins',
#  'Charterisio',
#  'Saverio Mercadante\n\n',
#  'MacKinnon',
#  'Louis Fleury\n\n',
#  'John Forous',
#  'Armstrong',
#  'Prix',
#  'Francesco Caccia',
#  'Patrick Ogyll',
#  'Hodgson',
#  'Mayville',
#  'George MacLeod',
#  'W. Heffer',
#  'Atom',
#  'Skene F',
#  'Katz',
#  'Res.6.46 Note',
#  'Spearman',
#  'Louis Fleury',
#  'James Nicol',
#  'Shwebo',
#  'Kozelka',
#  "Patrick M'Culloch",
#  'Willie Johnston',
#  'John Trulle',
#  'H Jawlowski',
#  'Highland Schottisches',
#  'Greco',
#  'John Spittal',
#  'Sheila M. Black',
#  'Charles Moldenhawer',
#  'D12 Dingwall',
#  'Alexander Darroch',
#  'William Evans',
#  'Margaret Diana',
#  'Knud Christian Jeppesen',
#  'Robert Hathowy',
#  'William Cuming',
#  'Malcolm Johnston',
#  'F. E. Waldron',
#  'Juno',
#  'Francis Bacon',
#  'Haya Maclugan',
#  'Midsummer',
#  'Theodore Berger\n\n',
#  'John Yocson',
#  'Robert Foulbery\n\n',
#  'Richard Blaklok',
#  'Victoria Terrace',
#  'LecturingProgrammesSchubert',
#  'Robert Parsons',
#  'Cavendish Sqr',
#  'John Oliphant',
#  'Bench Walk',
#  'Edinburgh Castle',
#  'John Neish Ritchie',
#  'John Gwyn Jeffreys',
#  'Johnston',
#  'Mary',
#  'Theresa Flynn',
#  'Bent Juel-Jensen',
#  'W. N. W. Watson\n\n',
#  'Gilbert [GreneLaw',
#  'John Hutton Balfour',
#  'Hugh Walas',
#  'Pavillon Gabrielles',
#  'Charles Mackinnon Douglas',
#  'Humphrey',
#  'W. John Haynes',
#  'Band V. Anatomie',
#  "Thomas Adam's",
#  'Michotte',
#  'John Richartsone',
#  'XLIX',
#  'George Robey',
#  'Donald MacKay',
#  'John Beill',
#  'Dorothy Stella Margaret',
#  'Elizabeth Anne\n\n',
#  "NoteJohn Baillie's",
#  'Paisley',
#  'Lodovick Duke',
#  'New Calton Jail',
#  'Robert] Graham of Fintry',
#  'Daughter 16.210',
#  'McClintock Lecture',
#  'John Grant',
#  'Eugenics Quarterly',
#  "Josephine Greenwood's",
#  'Ratho',
#  'Thomas Johnston',
#  'Thomas Wallang',
#  'Glasguen',
#  'Florence Houtton',
#  'Dorothy\n\nScope and',
#  'Esther Garke',
#  'Anne K. McMillan',
#  'W. Wainsupp',
#  'AustriaAlpbachKoestler',
#  'William Mair',
#  'Roman Prawochenski',
#  'London]ESPHaraldsson',
#  'D.D.',
#  'Helena Irvine Anne\n\nTitle',
#  'Dairying',
#  'Newburgh',
#  'Charles Hanbury Williams',
#  'Robert Kar',
#  'William Taylor',
#  'William Muirheid',
#  'Clarke',
#  'Roman',
#  'Manson',
#  'Michael Walkar',
#  'D.K.',
#  'Alexander Ingles',
#  'Saint-Gaudens',
#  'William Thomas',
#  "Discussng Grierson's",
#  'Grace Margaret',
#  'Johnson\n      ',
#  'James Darling',
#  'Alexander Culane',
#  'Marjorie Somerville',
#  'William Hunt',
#  'Frederica Kennedy-Erskine',
#  'Abraham Weinshall',
#  'William Herbert Hobbs',
#  'Robert Reid Walls',
#  'N. A. M.\n\n',
#  'Henry Congiltoun',
#  'Subject',
#  'John Rome',
#  'Roderick',
#  'Alex] Fraser',
#  'Jamieson',
#  'W. J. Sedgefield',
#  'Josselson',
#  'James Litill',
#  'Mary V\n\n',
#  'Malformed New-Born',
#  'Naomi Appleton',
#  'Duncan Kennedy',
#  'Margareth Galloway',
#  'Rodrick McLeod',
#  'Nicolas Ca',
#  'Ruxton',
#  'Mary Anne Everett Green',
#  'Ebenezer Henderson',
#  'Bloomfield',
#  'Mrs James Ryan',
#  'Thomas Cristesone',
#  'Robert Balldkyne',
#  'Wihelm von Nathusius',
#  'Long Barn',
#  'Froehlich',
#  'Ruth Waddell',
#  'Gilbert Pawtisone',
#  'John Kwyk',
#  'Jun',
#  'Edward Bannerman Ramsay',
#  'William Bar\xadbour',
#  "O. E. Berry'",
#  'Andrew Pop',
#  'Elliott',
#  'James Pillans',
#  'Arnott T. Wilson',
#  'Alexander Adam',
#  'W. S. Landon',
#  'Archibald Barklay',
#  'F. H. de Jonge',
#  'Toby Gough',
#  'Himalayan Haystacks',
#  'Warre Cornishes',
#  'John Colquhen',
#  'Kalendar',
#  'Thomas Peirson',
#  'Mary A Brown',
#  'Grace Milne-Home',
#  'Melton',
#  'Turbott',
#  'Senior Lecturer',
#  'P. Cappai',
#  'James Keith',
#  'Cawnpore',
#  'Londres',
#  'C. G.',
#  'Akio Kitamura',
#  'David Goss',
#  'Fersyth Clerk',
#  'James Carmichael\n\n',
#  'William Galbraith',
#  'T. L. E. Renall',
#  'Margaret Elizabeth Florence',
#  'Michael Lauder',
#  'John Auchinleck',
#  'Mary Felix DeMoville',
#  'G. B. S.',
#  'H. A. Scott\n\n',
#  'andSocrates(1933',
#  'Clashach',
#  'Roger Davidson',
#  'Gawin Hagerstoun',
#  'Robert Dickson\n\n',
#  'Martinus De Dassiez',
#  'Daniel Darly]\n\n',
#  'Long Horned',
#  'Annie T. Altschul]',
#  'M. Kuran',
#  'H. H. Dibdin',
#  'Marc-Andre-Raffalovich',
#  'Robert Stuart',
#  'Leszczynski',
#  'Walter] Runciman',
#  'A. Collinson',
#  'Dukinfield Henry Scott',
#  'Jas P. Muirhead',
#  'Recsey',
#  'C. Lai',
#  'Innerpeffray Library',
#  'Katherine Mary\n\n',
#  'Thomas Pawtonsone',
#  'Mary Agnes',
#  'Evesques Heretiques',
#  'Helburnisfurd',
#  'A.',
#  'Mayer Gross',
#  'James Hunter',
#  'Tuscany',
#  'David Ogilvie',
#  'Paul Hepburn',
#  'Gustav Holst',
#  'Jonet Mailvyn',
#  'E. S. P.',
#  'David Irving',
#  "Joan'",
#  'Brompton Sq',
#  'Jekyll',
#  'Neil Campbell',
#  'John Smeberd',
#  'Cuthbert Brown\n\n',
#  'John James Audubon',
#  'Henry Fairfield Osborn',
#  'Blackfriars Bridges',
#  'Alexander Maxwell',
#  'Patrick Hebburn',
#  'Adam Lausoun',
#  'Duncan Galbraith',
#  'Robert Heath',
#  'Childs Glacier',
#  'John B.',
#  'Jean Anderson',
#  'William Forbes',
#  'James Wyld',
#  "Warren G. Bennis;'Education",
#  'George Coffey',
#  'William Mures',
#  'John Foullar',
#  'Al-Masudi',
#  'James Forbes',
#  'Leslie George Cairns',
#  'Arthur Keith',
#  'J. Biely',
#  'Alan Couitis',
#  'Robert of Bugthrop',
#  'Henry Margenau',
#  'Walter Beton',
#  'Kylnum',
#  'Castledouglas',
#  'Irvine Welsh',
#  'Vlail',
#  'Granjon',
#  'Marie Gavan Duffy',
#  'Levi',
#  "G. Grieve'",
#  'William Striueling',
#  'Leith Walk',
#  'Ronald Luif',
#  'John Rait',
#  'Robert Pery',
#  'Leslie',
#  'T. R. Allinson\n\n',
#  "Colin Tudge's",
#  'Louis Hermann',
#  'Niddrie Kindergarten',
#  'Colston Bassett',
#  'Gillie',
#  'HD Goodale',
#  'Margaret Warre',
#  'Rev Duncan Crooks',
#  'Bauchi',
#  'C W Valentine',
#  'Bos',
#  'Edn',
#  'Nicholas del Lawe',
#  'John Thornton',
#  'Memling',
#  'Dr Kuenssberg',
#  'Cardenny Inches',
#  'Mrs M. Simpson',
#  'Mrs Barbara Murchison',
#  "James Clarkson Corson's",
#  'Galdos',
#  'Landour',
#  'K. Palmer',
#  'Polcre',
#  'William Marshall',
#  'Thom',
#  'D CESPHorrobin',
#  'Lude',
#  'Abraham Lawrence',
#  'William Eliasberg',
#  'Norman Dean',
#  'Gifford Lecturer',
#  'Pat',
#  'Lady Hereis',
#  'E.1982/40',
#  'Robert Arnot',
#  'Thou',
#  'Bungay',
#  "Norman MacCaig'",
#  'Dorothea Elizabeth',
#  'John P Mackintosh',
#  'John Alexander Robson Watt',
#  'Una Adamson',
#  'W H Bryce',
#  'Willem van de Velde',
#  'Kenneth Anderson',
#  'L Dodd',
#  'Adam Cunynghame',
#  'Miss Neaves',
#  'Marsigli',
#  'Nigel Trowp',
#  "George Mackenzie'sTravels",
#  'James Lawder',
#  'Absolute Checks',
#  'William Forsyth',
#  'Sumner',
#  'J. Ely',
#  'M. D. Vilelmi Leich',
#  'Cradle Song',
#  'A.G. Cock',
#  'AmI-B\n\n',
#  'Frances Dakyns',
#  'Buckhaven High',
#  'Ching Fon Pun',
#  'Trowell',
#  'Westerner',
#  'Branquellis',
#  'George F Manderson',
#  'Putney',
#  'Elliot',
#  'Andrew Trumbule',
#  'Fleetwood Edwards',
#  'Gamecock',
#  'Rontgen',
#  'Rose Haig Thomas',
#  'Gore',
#  'William Scheill',
#  'Balgouye',
#  'Inveresk',
#  'Cynthia Bernstein',
#  'Huub Schellekens',
#  'Cahier Arthur Koestler',
#  'Salome Gluecksohn-Waelsch',
#  'William Skirvein',
#  'W41 Woodburn',
#  'John Wellis',
#  'Teeswater Ram',
#  'John Laird',
#  'Anne Boyd',
#  'W. Henderson',
#  'Andrew Crawford Hume MRCVS',
#  'Lean Head',
#  'Cervantes',
#  'Edward Gibbon Wakefield',
#  "Josef Joachim'",
#  'Edward Utterson',
#  'Robert Bruce',
#  'Robert Campbell',
#  'Alfred James Hipkins\n\nTitle',
#  'Desmond\n\nScope',
#  'Bernadotte',
#  'Sophia Goudstikker',
#  'James [Kennedy',
#  'Alexander Petrovich Karpinsky(1894-1903)Aleksei',
#  'Henry G. Bohn',
#  'Thomas Biggar',
#  'John Abercrombie',
#  'James Hering',
#  'Janet S. B. Adams\n\n',
#  'N. McCreery',
#  'Thomas Dawson',
#  'Rotha',
#  'Ledermann',
#  'Roger Langlands',
#  'Glencoppok',
#  'Robert Bertram Serjeant',
#  'B. Ritchie',
#  'Magdalene Howden Balfour',
#  'Jonet White',
#  'A.M. Oberbauer',
#  'M41 Marston',
#  'David Mur',
#  'William Mason',
#  'Audrey Eckbo',
#  'Birth Certificate',
#  'Hal',
#  'Philosophia Naturalis',
#  'Content13pp',
#  'Quester',
#  'Thomas Grenelaw',
#  'James [Hay]',
#  'Heimito von\n\n',
#  'Anne Macpherson',
#  'Schultz',
#  'Uthred Knox',
#  'R. Cain',
#  'Paul Durcan',
#  'Fiona Stewart',
#  'Acacia',
#  'Weston Lane',
#  "M. Kennedy-Fraser'",
#  'Rein',
#  'Erskine',
#  'Elen Dudingstoun',
#  'Andrew Grant Bequest',
#  'William Pearce',
#  'Arthur Robertson Cushny',
#  'Balbadie',
#  'Psychopathic',
#  'Kindberg',
#  'Bartholomew Wawane',
#  'Michael Guyer',
#  'Liber de',
#  'George VI',
#  'Edward Dents',
#  'Jean M.',
#  'I.A Burkov',
#  'musician)Forde',
#  'Alison Murray Oliver',
#  'Jean MacLennan',
#  'Hew Rig',
#  'Thurn',
#  'Pass Certificates',
#  'David Gardin',
#  'Marjory Kennedy-Fraser)Kennedy',
#  'B. Clapperton',
#  'Mollie',
#  'Joseph E Wing',
#  'Paymaster',
#  'Lambrochtoun',
#  'Edmund Whittaker',
#  'G. C.:',
#  'Neil MacCormick',
#  'Lochkindeloch',
#  'Walter Dickson',
#  'Alexander Scott',
#  'Great Ormond Street',
#  'Laramie',
#  'Bever',
#  "Liber Canonicorum Regularium'",
#  'André Lwoff',
#  'C. J. G] to',
#  'Henry Bagge',
#  'Quad Concert',
#  'James Watt',
#  'McWhir',
#  'Patrick Nisbet',
#  'A.C. Choudhuri',
#  'Lady Walker',
#  'William of',
#  'Hallson',
#  'Zigler',
#  'P. W. Thomsons Dam\n\n',
#  'Siuuarde',
#  'Paul Waldo',
#  'Jahresbericht',
#  'William Martyn',
#  'Charles Kirkpatrick Sharpe',
#  "Thomas McKenny Hughes'",
#  'Medicine',
#  'Ferret',
#  'Bantock',
#  'Efik',
#  'Raphael Falk',
#  'Wiltshire Ram',
#  'Moredun Chair',
#  'Frances Busch',
#  'JE Deurden',
#  'Caldmertoun',
#  'Medeva',
#  'Leonard R. Bullas\n\n',
#  'Bruckner',
#  'Pitman',
#  'Emily Wesley',
#  'Jean Claudet',
#  'Richard Thomson',
#  'Res.4.27 Married',
#  'Meason',
#  'Mary Geraldine Grierson',
#  'Coles',
#  'Birger Persson',
#  'William Ritchie',
#  'Thomas Wade-Browne',
#  'Janet Dunbar',
#  'Aprilis',
#  'Khandmal',
#  'Cristopher Moncur',
#  'Anne McLaren',
#  'Victoria',
#  'Noelle Barkema',
#  'Maria Tazelaar',
#  'R. Allan',
#  'Indexp',
#  'Arthur Somervell',
#  'Champion Sam',
#  'Peter Ilich',
#  'John Smith Flett',
#  'Borquist',
#  'Jhonis',
#  'Carny',
#  "Steuart Denham's",
#  'Henry Strang',
#  'Alexander Thomsoun',
#  'Oswald Rae\n\nScope',
#  'E4 Name Withheld',
#  'Oliver',
#  'Cecil Thornton',
#  'William Akinhede',
#  'Mark Lun',
#  'James Wood',
#  'Tetsworth',
#  'Robert Fraser',
#  'Thomas Cuthbertson',
#  'Margaret Nairn',
#  'Lady Ruthven',
#  'Kindest',
#  'Richard Stuart',
#  'Coloquio -C14/14 - Genoma Humano - Valencia',
#  'Alexander Monro',
#  'Pacha Mehemet Ali',
#  'Trautwein',
#  'Brigham Pearl',
#  'Mrs Nealon',
#  'Hornpipes',
#  'Weingartner',
#  'Jonet Durham',
#  'Robert Moncur',
#  'Male INTVEE',
#  'Catherine I.',
#  'Percy Johnson',
#  'Baily',
#  'Miss Hill',
#  'George Bryson',
#  'Robert Bowden',
#  'Henry Whyte',
#  'Rae',
#  'Deirdre',
#  'Goood',
#  'F Vivian Gooch',
#  'E.A Schafer',
#  'Hertwiko De',
#  'Ecclesiam Errores',
#  'MacIntosh',
#  'Juan Carlos',
#  'the Glasgow Herald',
#  'Alfred L.',
#  'R.B Greig\n\n',
#  'Tessa Ransford',
#  'Mundell',
#  'Seeds',
#  'LamarckismGorczynski',
#  'John Osuald',
#  'Tyrtaeus',
#  'Hunter St',
#  'Balcarres',
#  'Charles L. Leeck',
#  'King Williams Town',
#  'Andrew More',
#  'ET Engle',
#  'Elizabeth Queen',
#  'Akademicai Kiado',
#  'Hog Aboard Ship',
#  'Paul M. Wright',
#  'John Baillie\n\n',
#  'H43 Name',
#  'Kilmacolm',
#  "Robert Knox's",
#  'Strathearn',
#  "Hans Andersen's",
#  'Alexander Howard',
#  'G52 Name',
#  'Thomas Sallirman',
#  'Catherine McIntyre',
#  'Jamie',
#  'Johnnie',
#  'Gilbert Duff',
#  'James Mortoun',
#  'E.M. Bradbury',
#  'John Nicholas',
#  'Arthur Balfour',
#  'Miklos Az',
#  'Hugh Douglas',
#  "J. Bigliardi-Rouvier 'Regulation de l'activite",
#  'Bourdet',
#  'Glasgow Necropolis',
#  'Hubert Hastings',
#  'St Kilda',
#  'George Earl',
#  'John Kincade',
#  'Crichton-Browne',
#  'Chillingham',
#  'Elizabeth Petkarne',
#  'AH Trow',
#  'John Jacob Holtzapffel',
#  'John Merscell',
#  'R.E.',
#  'Aufbau Reconstructionpp.1-2Sent',
#  'Mrs L',
#  'Patrick Crawfurd',
#  'Alex Pitcairn',
#  'O. S.',
#  'William G.',
#  'Andrew Baxendine',
#  'McClelland',
#  'Equivalenti',
#  'Zuckerman',
#  "de l'HerneArthur Koestler",
#  'George Campbell\n\n',
#  'John Oman',
#  'Khan Bull',
#  'David Donnison',
#  'Zandrini',
#  'John Stuard',
#  'Mark Nijhol',
#  'Arthur Sullivan',
#  'Brian Hara',
#  'Miss Balfour',
#  'WGC Bell',
#  'Mazoe [Rhodesia]\n\n',
#  "Water Bill'",
#  'Denney',
#  'Deane',
#  'Mary Wilkinson',
#  'Oliver Burght',
#  'William Balye',
#  'Diseases',
#  'Lean Sixes Bacon',
#  'Gretna Hall',
#  'Elizabeth Seton',
#  'Thomas Watho',
#  "de Cottoun'",
#  'Prem Narain',
#  'Thomas Cranstoune',
#  "Mary Grierson's",
#  'Tomas E. de Anchorena',
#  'John Pennington\n\n',
#  'D. Mackenzie',
#  'Paderewski',
#  'Liza Lehmann',
#  'Matthew Mortoun',
#  'Barbary',
#  'Donald J',
#  'TC Hope',
#  'C16 Caverhill',
#  'Stanley Hall',
#  'Thomas Thomsoun',
#  'James Smytht',
#  'Mendelssohn',
#  'John Leirmonth',
#  'Alexander Rose',
#  'M. Mill\n\n',
#  'Easter Carny',
#  'Langholm',
#  'Mary Keppel-Compton',
#  'Dr Greenwood',
#  'William Burke',
#  'Blase Lawrie',
#  'Charles Samuel Myers',
#  'William Blades',
#  'R. Thompson',
#  'Janet Turnbull',
#  'Chester M.\n\n',
#  'Constance McDavey',
#  'Tony Burne',
#  'Thomas Folbery',
#  'John W. Turner',
#  'K. Murchison',
#  'John Rotch',
#  'F. W. Deas',
#  'Henry Gall\n\n',
#  "Donald Francis Tovey' II",
#  'Currie Powder',
#  'CE Hayden',
#  'James Frisken',
#  'Lister Memorial Scheme - 3',
#  'de',
#  'Kulturelle Freiheit',
#  'Willie Wastle',
#  'Alexander Broyse [Bruce]',
#  'Alexander Mowbray',
#  'Alexander Cuningham',
#  'Thomas Lawtay',
#  'Harry W Titus',
#  'DT Macdougal',
#  'Harold P. Klinger',
#  'Scott St.',
#  "John M'Gillwye",
#  'William McEwan',
#  'R. G. McKinnell',
#  'Yehuda Litani - Diary',
#  'Maud Grundy',
#  'Parratt',
#  'Robert Henderson',
#  'Gavin Walker',
#  'T. F. Torrance',
#  'James Leslie',
#  'John Breg',
#  'Andrew Crichton',
#  'Eduardo Paolozzi',
#  'Background',
#  'George Taylor',
#  'Margaret Read',
#  'Edward Carter',
#  'Fra Angelico',
#  'J Hammond',
#  'William Gordon Burn-',
#  'Hyman Levy',
#  'Beethoven Lieder\n\n',
#  "Frank Lilly's",
#  'Dyocis Tempill\n\n',
#  'Alex',
#  'Alexander Adamsone',
#  'Suzanne',
#  'Tamworth Sow',
#  'Mathias De Chaystowicz',
#  'Jonet Gibson',
#  'R. Meehan',
#  "T. W. Stirling's",
#  'Allan G Rodger',
#  "Précis de l'art",
#  'J. Bowering',
#  'Anthony Cronin',
#  'Alison Keen',
#  'Alexander Broun',
#  'James Hornby',
#  'PEP',
#  'George Christopher Molesworth Birdwood',
#  'Faulkner',
#  'William Currour',
#  "Snuff Box'",
#  'Salve Christian Fredrik Salvesen',
#  'ofNihayat Al-Rutba',
#  'McCreery',
#  'Linton',
#  'M.B.E Godward',
#  'Pauline Owen\n\n',
#  'Alexander Conyngham',
#  'Henry Trotter',
#  "'Gene Transfer",
#  'David Peter Chalmers',
#  'Biochemistry Departments',
#  'Informing Grierson',
#  'Pollock',
#  'Jessie Margaret',
#  'Paula Hertwig',
#  'Lyle V Jones',
#  'James Coupar Brash',
#  'Daniel Wakefield',
#  'Deitrich Bonhoeffer',
#  'Pompeo Ugoni',
#  'Olivier',
#  'William Carrick',
#  'Louis Philippe',
#  'We-Z',
#  'Jhon',
#  'c1900s',
#  'Antonio Caldara',
#  'Charles Goodnight',
#  'Mary Combe',
#  'Poster;Seminar Report',
#  'C. Carolan',
#  'Edward F.',
#  'Walter Ross',
#  'Albert Hinnen',
#  'Vico',
#  'Maxwell Garnett',
#  'Von Reinhardt',
#  'Ronald; Walker',
#  'Sprigge',
#  'Alex Brunton',
#  'Thomas Baxter',
#  'Henry Ellis',
#  'Mott',
#  'Bartill Smeberd',
#  'James Dwight Dana',
#  'Alexander Hay',
#  'L22 Lang',
#  'William Bradfutt',
#  'Pearce',
#  'Thomas Gardin',
#  'Sc',
#  'Glyndebourne',
#  'H55 Hawley',
#  'F. S. Kelly\n\n',
#  'Khairigarh',
#  'Jhon Lawmont',
#  'Elizabeth Pickerly',
#  'John Rauff',
#  'Janet Robertson',
#  'Keris',
#  'William Richardson\n\n',
#  'Behrens',
#  'D. Long',
#  'C. A. R. McRae',
#  'Mr McCallum',
#  'Cuthbert Baty',
#  'Gavin Hamilton',
#  'An Deo-Gréine',
#  'Fraser-Roberts',
#  'Miner',
#  "Bill Hayes'",
#  'Samuel Hibbert-Ware',
#  'Kemp',
#  'David Owen',
#  "S. Uist'",
#  'Experiment Garden CornerCutten',
#  'Salton',
#  'James T. Gibson-Craig',
#  'George Turcan Chiene',
#  'Arthur Dean',
#  'Robert James Blair Cunynghame',
#  'HF Krallinger',
#  "Mrs MacDougall's",
#  'James Kerr',
#  'Bernard Baillie',
#  'John J. Bonar',
#  'Robert Davidson',
#  'Chyna De Pawlow',
#  'Merino Ram',
#  'George Lewyntoun',
#  'Locharthur',
#  'Irene Young',
#  'S. Codegrand',
#  'Alexander Erskine',
#  'Gibbotistun',
#  'Charles Kennett Burrow',
#  'Margaret Wedderat',
#  'George Augustus Sala',
#  'Ira Einhorn1p',
#  'Maurice Adams',
#  'Ballinbreich',
#  'Marr',
#  'Greenwood Genetics',
#  'Bogdandy',
#  'David Dunlop',
#  'David Pringill',
#  'Elizabeth Margaret',
#  'James Vincent',
#  'Begum',
#  'Creutzfeldt-Jakob',
#  'Elsa Dohnanyi-Salapes\n\n',
#  'Walsh',
#  'John Makquhon',
#  'Walter Henrison',
#  'Lady Montague',
#  'Robert Reid',
#  'John Couper',
#  'Jedburgh Roxburghshire',
#  "Monasterii Dulcis Cordis'",
#  'Theydon BoisSent',
#  'J. Needham',
#  'Lessons',
#  'David I',
#  'Jamsetjee Bund',
#  'A. Conan Doyle',
#  'Douglas McKie',
#  'Norman McOmish Dott',
#  'David Talbot',
#  'Walford Davis',
#  'Vic',
#  'David Thomson',
#  'John Barbour',
#  'Thomas Corson',
#  'Kinblethmont House',
#  'Alexander Swan',
#  'W Gregory',
#  'Alexander Agassiz',
#  'Anna Elizabeth',
#  'Khandagiri',
#  'W. Oettingen',
#  'Brian George Thompson',
#  'G. T.',
#  'Duchess Sforza Cesarini',
#  'Jane Hutchinson',
#  'William Stokes',
#  'Giles Farnaby',
#  'St Mirren Paisley\n\n',
#  'Helen Elizabeth\n\n',
#  'William Hird',
#  'Gavin',
#  'Florence Bruce Dorward',
#  'A. Kennick',
#  'John Paton',
#  'CE Skinner',
#  'Proposal',
#  'Jennie Hutchinson',
#  'Urteilskraft',
#  'Cyril B.',
#  'Harold Wilson',
#  'E. Hind',
#  'Academie Bulgarie des Sciences',
#  'Thomas Wawane',
#  'G W',
#  'Pat Simpson',
#  'Monica',
#  'James Court',
#  'JO Foley',
#  'John of Carlisle',
#  'Vica',
#  'Stem Cells',
#  'Thomas Beecham',
#  'Malcolm\n\n',
#  'Hampshire Rams',
#  'Helmut Schmidt',
#  'John Carmychaell',
#  'James Dalrymple c.1774',
#  'Tilton',
#  'Dolphinton',
#  'Thomas Dewar',
#  'Algernon',
#  'Jeanne Winifred\n\n',
#  'John Westuater',
#  'Anthony Cruz',
#  'Edith Fairlie\n\nTitle',
#  'Priscilla Wakefield',
#  'Alexander Dunbar',
#  'Ninian Dowglas',
#  'Craighall',
#  'Charles Grant Robertson\n\n',
#  'Hawthornden Castle and Tyninghame House',
#  'Stirrat',
#  'Co. Glasgow',
#  'Kathleen Worster',
#  'J. R. Friedenthal',
#  'A. Ainslie',
#  'Fuertefentura',
#  'Banffshire',
#  'John Henry Newman',
#  'Janet S. S. Blyth',
#  'Burleigh',
#  'Bush',
#  'Gregorio XIII',
#  'Robert Bowis',
#  'John G. Bartholomew',
#  'Walter Striueling',
#  'James Halyday',
#  ...]

# %% [markdown]
# Not perfect...some non-person entities labeled such as `Londres` and `Snuff Box`.  I'll add labeling person names to the annotation instructions!

# %% [markdown]
# <a id="check-dups"></a>
# ## III. Checking for Duplicate Descriptions

# %%
descs = PlaintextCorpusReader("lucy_final (copy)/", ".+\.txt")
fileids = descs.fileids()
descs.raw(fileids[0])
# Out:
# "Identifier: AA5\n\nTitle:\nPapers of The Very Rev Prof James Whyte (1920-2005)\n\nScope and Contents:\nSermons and addresses, 1948-1996; lectures, 1949-1982; class notes and lecture notes, 1949-1982; correspondence, 1988-1989 and 1964-1970; newspaper cuttings, 1988-1989 and 1964-1969; publications and articles, 1902-1970; church magazines, 1929-1993; conference papers, 1978; moderatorial papers, 1988-1989; University Christian Consultative Group papers, 1970-1972; Church of Scotland and the Congregational Union of Scotland papers, 1959-1967; personal papers, 1848-1983; photographs 1911 and 1960.See also External Documents (below).\n\nBiographical / Historical:\nProfessor James Aitken White was a leading Scottish Theologian and Moderator of the General Assembly of the Church of Scotland. He was educated at Daniel Stewart's College and the University of Edinburgh where he studied philosophy and divinity. After his ordination he spent three years as an army Chaplain and then in 1948 was inducted to Dunollie Road Church in Oban. James Whyte moved to Mayfield North Church in Edinburgh in 1954 and in 1958 was appointed to the chair of practical theology and Christian ethics at the University of St Andrew's where he remained until 1987. His primary interests were in liturgy and ecclesiastical architecture and he also lectured on pastoral care.\nJames Whyte was called upon to preach at the memorial service for the victims of the Lockerbie disaster on 4th January 1989. The service was relayed around the world and was widely cited in the press having had a great impact. The full text of this sermon was published in Laughter and Tears: Thoughts on Faith in the Face of Suffering (Edinburgh, St Andrew's Press, 1993).\n"

# %%
x = descs.raw(fileids[0])
x.split("\n")
# Out:
# ['Identifier: AA5',
#  '',
#  'Title:',
#  'Papers of The Very Rev Prof James Whyte (1920-2005)',
#  '',
#  'Scope and Contents:',
#  'Sermons and addresses, 1948-1996; lectures, 1949-1982; class notes and lecture notes, 1949-1982; correspondence, 1988-1989 and 1964-1970; newspaper cuttings, 1988-1989 and 1964-1969; publications and articles, 1902-1970; church magazines, 1929-1993; conference papers, 1978; moderatorial papers, 1988-1989; University Christian Consultative Group papers, 1970-1972; Church of Scotland and the Congregational Union of Scotland papers, 1959-1967; personal papers, 1848-1983; photographs 1911 and 1960.See also External Documents (below).',
#  '',
#  'Biographical / Historical:',
#  "Professor James Aitken White was a leading Scottish Theologian and Moderator of the General Assembly of the Church of Scotland. He was educated at Daniel Stewart's College and the University of Edinburgh where he studied philosophy and divinity. After his ordination he spent three years as an army Chaplain and then in 1948 was inducted to Dunollie Road Church in Oban. James Whyte moved to Mayfield North Church in Edinburgh in 1954 and in 1958 was appointed to the chair of practical theology and Christian ethics at the University of St Andrew's where he remained until 1987. His primary interests were in liturgy and ecclesiastical architecture and he also lectured on pastoral care.",
#  "James Whyte was called upon to preach at the memorial service for the victims of the Lockerbie disaster on 4th January 1989. The service was relayed around the world and was widely cited in the press having had a great impact. The full text of this sermon was published in Laughter and Tears: Thoughts on Faith in the Face of Suffering (Edinburgh, St Andrew's Press, 1993).",
#  '']

# %%
descs_split = []
for fileid in fileids:
    d = descs.raw(fileid).split("\n")
    for section in d:
        if len(section) > 0:
            if "Identifier" not in section and "Title" not in section and "Scope and Contents" not in section and "Biographical / Historical" not in section and "Processing Information" not in section and "No information provided" not in section:
                descs_split += [section]
print(descs_split[0:4])
# Out:
# ['Papers of The Very Rev Prof James Whyte (1920-2005)', 'Sermons and addresses, 1948-1996; lectures, 1949-1982; class notes and lecture notes, 1949-1982; correspondence, 1988-1989 and 1964-1970; newspaper cuttings, 1988-1989 and 1964-1969; publications and articles, 1902-1970; church magazines, 1929-1993; conference papers, 1978; moderatorial papers, 1988-1989; University Christian Consultative Group papers, 1970-1972; Church of Scotland and the Congregational Union of Scotland papers, 1959-1967; personal papers, 1848-1983; photographs 1911 and 1960.See also External Documents (below).', "Professor James Aitken White was a leading Scottish Theologian and Moderator of the General Assembly of the Church of Scotland. He was educated at Daniel Stewart's College and the University of Edinburgh where he studied philosophy and divinity. After his ordination he spent three years as an army Chaplain and then in 1948 was inducted to Dunollie Road Church in Oban. James Whyte moved to Mayfield North Church in Edinburgh in 1954 and in 1958 was appointed to the chair of practical theology and Christian ethics at the University of St Andrew's where he remained until 1987. His primary interests were in liturgy and ecclesiastical architecture and he also lectured on pastoral care.", "James Whyte was called upon to preach at the memorial service for the victims of the Lockerbie disaster on 4th January 1989. The service was relayed around the world and was widely cited in the press having had a great impact. The full text of this sermon was published in Laughter and Tears: Thoughts on Faith in the Face of Suffering (Edinburgh, St Andrew's Press, 1993)."]

# %%
len(descs_split)
# Out:
# 105111

# %%
len(set(descs_split))
# Out:
# 81622
