# %% [markdown]
# # Identifying People in CDCS Metadata Descriptions
# Run named entity recognition (NER) on the metadata descriptions extracted from the CDCS' online archival catalog.
#
# The code in this Jupyter Notebook is part of a PhD project to create a gold standard dataset labeled for gender biased language, on which a classifier can be trained to identify gender bias in archival metadata descriptions.
#
# This project is focused on the English language and archival institutions in the United Kingdom.
#
# * Author: Lucy Havens
# * Date: November 2020 - February 2021
# * Project: PhD Case Study 1
# * Data Provider: [ArchivesSpace](https://archives.collections.ed.ac.uk/), Centre for Research Collections, University of Edinburgh
#
# ***
#
# **Table of Contents**
#
#   [I. Corpus Statistics](#corpus-stats)
#
#   [II. Named Entity Recognition with SpaCy](#ner)
#
#   [III. Checking for Duplicate Descritions](#check-dups)
#
# ***

# %%
import pandas as pd

import nltk
from nltk.tokenize import word_tokenize
from nltk.tokenize import sent_tokenize
# nltk.download('punkt')
from nltk.corpus import PlaintextCorpusReader
# nltk.download('averaged_perceptron_tagger')
from nltk.corpus import stopwords
# nltk.download('stopwords')
from nltk.tag import pos_tag
import string
import csv
import re

import spacy
from spacy import displacy
from collections import Counter
try:
    import en_core_web_sm
except ImportError:
    print("Downlading en_core_web_sm model")
    import sys
    # !{sys.executable} -m spacy download en_core_web_sm
else:
    print("Already have en_core_web_sm")
import en_core_web_sm
nlp = en_core_web_sm.load()
# Out:
# Already have en_core_web_sm

# %% [markdown]
# <a id="corpus-stats"></a>
# ## I. Corpus Statisctics

# %%
descs = PlaintextCorpusReader("../AnnotationData/descriptions_by_fonds_split_with_ann/descriptions_by_fonds_split_with_ann/", ".+\.txt")

# %%
tokens = descs.words()
print(tokens[0:20])
# Out:
# ['Identifier', ':', 'AA4', 'Title', ':', 'Papers', 'of', 'Rev', 'Prof', 'John', 'McIntyre', '(', '1916', '-', '2005', ')', 'Scope', 'and', 'Contents', ':']

# %%
sentences = descs.sents()
print(sentences[0:5])
# Out:
# [['Identifier', ':', 'AA4'], ['Title', ':', 'Papers', 'of', 'Rev', 'Prof', 'John', 'McIntyre', '(', '1916', '-', '2005', ')'], ['Scope', 'and', 'Contents', ':', 'Sermons', 'and', 'addresses', ',', '1940', '-', '1997', ';', 'personal', 'papers', ',', '1932', '-', '2006', ';', 'lectures', ',', '1946', '-', '1990', ';', 'class', 'notes', 'and', 'lecture', 'notes', ',', '1932', '-', '1941', ';', 'correspondence', ',', '1979', '-', '1983', ';', 'papers', 'relating', 'to', 'the', 'Dean', 'of', 'the', 'Thistle', ',', '1974', '-', '1980', ';', 'newspaper', 'cuttings', ',', '1945', '-', '1982', ';', 'publications', 'and', 'articles', ',', '1929', '-', '1987', ';', 'essays', ',', '1935', '-', '1979', ',', 'audio', 'cassette', 'tapes', ',', '1987', 'and', 'papers', 'relating', 'to', 'television', 'broadcasts', ',', '1960', '-', '1967', '.', 'See', 'also', 'External', 'Documents', '(', 'below', ').'], ['Biographical', '/', 'Historical', ':', 'John', 'McIntyre', '(', '1916', '-', '2005', ')', 'was', 'born', 'in', 'Glasgow', ',', 'educated', 'at', 'Bathgate', 'Academy', 'and', 'then', 'Edinburgh', 'University', 'where', 'he', 'graduated', 'in', 'philosophy', 'and', 'then', 'in', 'divinity', '.'], ['In', '1943', 'he', 'became', 'the', 'minister', 'of', 'the', 'Ayrshire', 'village', 'of', 'Fenwick', 'before', 'leaving', 'Scotland', 'in', '1945', 'to', 'teach', 'theology', 'at', 'St', 'Andrew', "'", 's', 'College', 'in', 'the', 'University', 'of', 'Sydney', '.']]

# %%
def corpusStatistics(plaintext_corpus_read_lists):
    total_chars = 0
    total_tokens = 0
    total_sents = 0
    total_files = 0
    
    # fileids are the TXT file names in the nls-text-ladiesDebating folder:
    for fileid in plaintext_corpus_read_lists.fileids():
        total_chars += len(plaintext_corpus_read_lists.raw(fileid))
        total_tokens += len(plaintext_corpus_read_lists.words(fileid))
        total_sents += len(plaintext_corpus_read_lists.sents(fileid))
        total_files += 1
    
    print("Total Estimated...")
    print("  Characters:", total_chars)
    print("  Tokens:", total_tokens)
    print("  Sentences:", total_sents)
    print("  Files:", total_files)

corpusStatistics(descs)
# Out:
# Total Estimated...
#   Characters: 13739019
#   Tokens: 2754044
#   Sentences: 156124
#   Files: 3649

# %%
words = [t for t in tokens if t.isalpha()]
print("Total Estimated Words:",len(words))
# Out:
# Total Estimated Words: 2006380

# %%
to_exclude = set((stopwords.words("english")) + ["Title", "Identifier", "Scope", 
                "Contents", "Biograhical", "Historical", "Processing", "Information"]
                )
words = [w for w in words if w not in to_exclude]

# %%
print("Total Words Excluding Metadata Field Names:",len(words))
# Out:
# Total Words Excluding Metadata Field Names: 1273237

# %% [markdown]
# <a id="ner"></a>
# ## II. Name Entity Recognition with spaCy
# Run named entity recognition (NER) to estimate the names in the dataset and get a sense for the value in manually labeling names during the annotation process.

# %%
fileids = descs.fileids()

# %%
sentences = []
for fileid in fileids:
    file = descs.raw(fileid)
    sentences += nltk.sent_tokenize(file)

# %%
person_list = []
for s in sentences:
    s_ne = nlp(s)
    for entity in s_ne.ents:
        if entity.label_ == 'PERSON':
            person_list += [entity.text]

# %%
unique_persons = list(set(person_list))
print(len(unique_persons))
# Out:
# 28625

# %%
unique_persons
# Out:
# ['Twynholm Manse',
#  'Owen',
#  'Christopher Dawson',
#  'Archibald Lindesay',
#  'William Fordaill',
#  'Christmas Card',
#  'Headteacher',
#  'Goulstonian Lecturer',
#  'Nicholas Thoums',
#  'Melvin J.',
#  'Lila Black',
#  'H. Tregellas',
#  'Mary Tovey',
#  'Children',
#  'Ein Beitrag',
#  'A. McLaren',
#  'Tayne',
#  'William S. Morrison',
#  'John Brownlee',
#  'J.H Sang',
#  'Group Almoner',
#  'Mme Laure Mitchell',
#  'Daemonologie',
#  'S. Karger',
#  'Steve Byrne',
#  'Amal Chandra Chaudhuri',
#  'Fallowis',
#  'Chekhov',
#  'Henry Tristram',
#  'Andrew More',
#  'Mrs Adele Koestler',
#  'Sewaltoun',
#  'Walter Harris',
#  'Willie',
#  'Steen Willasden',
#  'Donald Watterson',
#  'George Low',
#  'MD PhD',
#  'Patrick Hepburn',
#  'Bindan Blood',
#  'Hugh Macfarlane',
#  'Simon',
#  'F. Duthie',
#  'D5 Donovan',
#  'William Rerik',
#  'Jeremy Bentham',
#  'Raphael Falk',
#  'Curly Lop-Eared Lincoln Sow',
#  'Thomas Dikkesone',
#  'P. Brown',
#  'David Weir',
#  'Mula Rosoff',
#  'Belech De',
#  'Richard Fitz John',
#  'Gilbert Lawdir',
#  'Chesney',
#  'Begri',
#  'Alexander Petrovich Karpinsky(1894-1903)Aleksei',
#  'Northumberland Tests - Arithmetic',
#  'Pere Lachaise',
#  'Paul Wittgenstein',
#  'John Castarris',
#  'Peter Cocherane',
#  'Frederik Schien',
#  'John Alexander Lamb',
#  'Charles-Bertin-Gaston',
#  'David Donaldsone',
#  'Jeremy Montagu',
#  'William Stirlng Maxwell',
#  'Annie Macpherson',
#  'Maria Murray',
#  'Stewart Hore-Brown',
#  'Kirk Newton',
#  'G Macmullen',
#  'Thomas Inche',
#  'Gill Sans',
#  'Peter Hall',
#  'Alexander Hunman',
#  'William Fullarton',
#  'Paul IV',
#  'Hypothec',
#  'Oliver Burght',
#  'John Jaksone',
#  'Henry Huxley',
#  'Jeannie Wilson',
#  'Alexander H. Main\n\nBiographical / Historical',
#  'Blackett',
#  'Robert Menzies',
#  'Bakewell',
#  'Roma',
#  'Tewkesbury',
#  'Clara Gould ]\n\n',
#  'Glamis Castle',
#  'William Edward Norris',
#  'recipient[Sadleir',
#  'Iacobi Douglas',
#  'Adam Landels',
#  'Sanctorum',
#  'Royal',
#  'Robert Struther',
#  'Robert Lyndsay',
#  '278.CorrespondenceFraser',
#  'A. Holland',
#  'Mary M\n\n',
#  'B68 Boyd',
#  'George Hutchesone',
#  "Lady Lothian'",
#  'De Swart',
#  'Johannes De Lestowicz',
#  'Hansi Nagore',
#  'John Hirde',
#  'Maud C. Gilton',
#  'James Scott Bowerbank',
#  'Nikolai Krementsov',
#  'Quad Concert',
#  'Andrew Lindsay',
#  'Unwin',
#  'Sharrpey-Schaffer',
#  'Sheeps Fescue',
#  'John Braine',
#  'Mainz',
#  'Lamancha',
#  'Margaret Balfour',
#  'Jacobite',
#  'Catherine Cowan',
#  'Principal Clerk',
#  'Hugh Congilton',
#  'Thomas Loveday',
#  'Bruce Maclean',
#  'Bosendorfer',
#  'William Home Cook',
#  'D de Winton',
#  'St Vincent',
#  'Maurice Duhamel',
#  'George William Stow',
#  'Alexander Murray\n\n',
#  'Helen Chalmers',
#  'Alexander Caboll',
#  'Nancy',
#  'David Brewster',
#  'A.H. Wratislaw',
#  'Russell F Gwinnell',
#  'Bursae Mucosae',
#  'William Heron',
#  'van Zwichem',
#  'Winston Scott Memorial Lecture',
#  'Gershwin',
#  'George Steuart Mackenzie of Coul, Baronet',
#  'F. Tessier',
#  "Thomas M'Vcthee",
#  'Miss Weisse',
#  'Anna',
#  "D. Mem'a",
#  'Julius Wellhausen',
#  'Alexander Morton',
#  'Hugh Gourlaye',
#  'William Blakeley',
#  'Bad Scuol',
#  "O'Cailleach",
#  'William Jobsoun',
#  'Robert D. Underwood',
#  "Hans Gals's",
#  'Haggard',
#  'Kristy Davis',
#  'Stokes',
#  'Belfestinio',
#  'MS)Larkin',
#  'Thomas Lyndesay',
#  'Catherine II',
#  'Cert MD',
#  'William Ainslie',
#  'John Warden',
#  'Mrs Hart',
#  'Walter\n\n',
#  'Burdon Miller',
#  'Adele\n\nScope and Contents',
#  'James Simpson',
#  'Davis',
#  'Ho',
#  'Expert',
#  'George Narne',
#  'John Tyry',
#  'Manjra Singhai',
#  'Robert Craufurd',
#  'David Magee',
#  'C. R. M. Banks\n\n',
#  'Miss Cicely D Fawcet',
#  'William Neische',
#  "John M'Kennedy",
#  'William Vobstar',
#  'Minnie Punton',
#  'Selkirk Players',
#  'Frozen Meat\n\n',
#  'Pamela Margaret Kingston',
#  'John Forrester',
#  'Arnold Bax',
#  'Won',
#  'William of Borthik',
#  'Ian M. MacIntosh',
#  'James Reid\n\n',
#  'William Pettillok',
#  'James Millar Lowe',
#  'Secondary Keys',
#  'Edward Percival Wright',
#  'William Merryman',
#  'Statistical Hypotheses',
#  'Idiocy\n\n',
#  'J Needham',
#  'Queen Empress',
#  'Paul Hindemith',
#  'Kert',
#  "James Gillespie's",
#  'B.Litt',
#  'William Thorn',
#  'John Pitcairn Mackintosh MP',
#  'Confidential Returns',
#  'C. H. Bond\n\n',
#  'Adam House',
#  'Groningen',
#  'Michael Donaldsoun',
#  'Robert Lawdyr',
#  'Bacterias',
#  'H. A. Scott\n\n',
#  'James Matthew',
#  'Prosper Bysshe',
#  'John Tulloch',
#  'Margaret Creichtoun',
#  'Faked Horns',
#  'Patrick Sydsarf',
#  "Charles V'",
#  'Maurice of Ewrth',
#  'Dalyhell',
#  'Henry Gannett',
#  'Lauckner',
#  'Margaret G. Winfield',
#  'Thomas Bancroft',
#  'H61 Hindley',
#  'Leigh Hoadley',
#  'Alexander Pastoune',
#  'R. Thompson',
#  'Reg H.',
#  'Anthony H',
#  'John Wain',
#  'Basil Urwin',
#  'F Schrader',
#  'Suton Coldfield',
#  'David Hoppringyll',
#  'Bertram Christian',
#  'David Bell',
#  'Robert Raith',
#  'James Rick',
#  "John M'Gachin",
#  'Allan McNeil',
#  'James Menzeis',
#  'Monk Bretton',
#  'Jura',
#  'Robert Homer Burns',
#  'Elizabeth Lyon',
#  "St James'",
#  'Whitlock',
#  'John George Bartholomew',
#  'John Kylpatryk',
#  'Holzinger',
#  'Markham',
#  "Henry VIII's",
#  'Padhye',
#  'Trumps',
#  'Zihuatanejo LSD',
#  'George Henschel',
#  'Librarian',
#  'Miss Stevenson',
#  'Lewis Lukens',
#  'Walter Ross',
#  'James Bennie',
#  'Westerner',
#  'Adam Conyghame',
#  'Rosing',
#  'Walt Whitman',
#  'Geron',
#  'John A Roan',
#  'Zavattini',
#  'Thomas Nichol',
#  'Cunnamulla',
#  'David Pitcairn',
#  'M. Drysdale',
#  'Young',
#  'Walter Gray',
#  'Cocksey',
#  'K. R. McLaren',
#  'Barker',
#  'Thomas Thomson / Minto',
#  'Magdalene Lodge',
#  'H. Takahashi',
#  'Derek Findlay',
#  'Kundi Buffalo Cow',
#  'Shapes',
#  'Warren Poppino',
#  'Brian Clarke',
#  "Patrick Macdonald's",
#  'Pollock Halls of Residence',
#  'George Lord Haliburton',
#  'Gallop',
#  'John Hammylton',
#  'Kenneth Alsopp',
#  'Alexander Melvill',
#  'James Tylter',
#  'Wilmut',
#  'George Fryslyn',
#  'Craven St. London',
#  'John Buntyng',
#  'Allan G Tweedie',
#  'George C. Harrap',
#  'de Kelder',
#  'GS Huntington',
#  'Bolton',
#  'Helen Sutherland',
#  'William Howard Taft',
#  'Haggs',
#  'Denney',
#  'David [Hamilton]',
#  'Mann',
#  'J. P. Pemberton',
#  'John Bartan',
#  'Alan Hamilton',
#  'John Byer',
#  'LondonESP',
#  'this Gilbert Browne',
#  'Economic History',
#  'Mary Wilson',
#  'G. Grassmann\n\n',
#  'MS_BOX_17',
#  'George France',
#  'Beloff',
#  'Christina Young',
#  'Noble',
#  'Agnes Stewart',
#  'Margaret Campbell Scott',
#  'John Brounhill',
#  'Freman',
#  'David Bait',
#  'Cambuskennet',
#  'Donald Dow',
#  'Robert Fleming',
#  'Earl John',
#  "W. Eichrodt's",
#  'Edward Story',
#  'Thomas Coustoun',
#  'John Belay',
#  'Daniel Darly] to',
#  'Myrtoun',
#  'Haifa',
#  'Nigel\n\nScope and',
#  'Cunningham Lectures',
#  'Saint Julien - LL',
#  "Mary Erskine's",
#  'Gorgie',
#  'Percy William Page Bedford',
#  'John Glen',
#  "JMD Mieklejohn's",
#  'Charles Augustus Hartley',
#  'Jonet Durham',
#  'Hypomania',
#  'Bego',
#  'William Strothere',
#  'Alexander Johnston\n\n',
#  'Geographical',
#  'George Cuyk',
#  'Othmar',
#  'Dunkeld',
#  'Margaret Cooper',
#  'Alison M.\n\n',
#  'Granville Ransome Bantock',
#  'Augustus Square',
#  'John Mortymare',
#  'Christina McLaren',
#  'James Augustus Henry Murray',
#  'William Turner',
#  'Harry Luke',
#  'Memoirs Grzybowski',
#  'Kirk',
#  'Bálint Vajta',
#  'Winifred Donaldson',
#  'Civil Engineer',
#  'John Howie',
#  'R. Siuuarde',
#  'W K',
#  'Carrick Hill',
#  'R Robison',
#  'John Maknill',
#  'Bertha Oser',
#  'Walter Lany',
#  'John Hay',
#  'Eton Orchestra',
#  'Sofia Murller',
#  'Janet Munro',
#  'John Dowgall',
#  'Henry John Elwes',
#  'Pangloss',
#  'Andrew Simsoun',
#  'Jessie King',
#  'Eric Eaglesham',
#  'Alice Shaw',
#  'William Ferquhar',
#  'John Phillop',
#  'Kirkhope',
#  'William Duncan',
#  'H. Ogden',
#  'Willielma Campbell',
#  'Francis Dashwood',
#  'Malcolm Drummond',
#  'Thomas Cranstoune',
#  'Bruce Henderson Kenrick',
#  'Schumacher',
#  'George Haitlie',
#  'Andrew Lumsden',
#  'Cheryl Mendelson',
#  'David Foret',
#  'Small',
#  'Lady Halle',
#  'Grace Robb',
#  'James Aikman',
#  'C77 Cameron',
#  'John of Strivelyn',
#  'Worthington',
#  'Thomas Wemys',
#  'George Lundy',
#  'David Dugeoun',
#  'Edward H.:',
#  'Chelsea',
#  'Sibelius',
#  'Jeannie Robertson\n\nScope',
#  'George W. Corner',
#  'Percy Johnson-Marshall Collection',
#  'D. Laughton',
#  'EP Boas',
#  'Robert Ra',
#  'Adam Lumsden',
#  'Putnam',
#  'George Boswell',
#  'Donald Moodie',
#  'Benjamin Neeve Peach to Lanarkshire',
#  'Alexander Broyse [Bruce]',
#  'Hepatitis B. Biogen',
#  'Cuthbert Greirson',
#  'Worthing',
#  'Henry Walles',
#  'Diploma',
#  'David Dempster',
#  'Gioacchini Rossini\n\n',
#  'William WhitakerSir Charles William WilsonEdward Adrian WilsonJohn WilsonHorace',
#  'William Laidlaw\n\n',
#  'BUSH',
#  'Adam Dikesoun',
#  'David Ross Stadler\n\n',
#  'Alex Greig',
#  'James Higgs]\n\n',
#  'Abbotshall',
#  'Charles Stewart\n\n',
#  'A. Fuller - Maitland',
#  'Fynlastoun Cuningham',
#  'William Gladstone',
#  'David Haswell',
#  'Gu',
#  'John Binnie',
#  'Rubinstein',
#  'Eleonora Russell',
#  'Iytell Kenne',
#  'Johansson',
#  'Gabor',
#  'C22 Chisholm',
#  'J. Mandelstam',
#  'Mathew Stewart',
#  'James [Crichton',
#  "Mairì Laghach' '",
#  'Dippenneis Easter',
#  'Moonstone',
#  'Soccer',
#  'A. Morrison',
#  'S66 Scott',
#  'Hilda C. McCrae',
#  'Vernon Watkins',
#  'Robert Bailze',
#  'John Aldinstoun',
#  'Khandmal',
#  'Athabasha Landing',
#  'Edward Annan',
#  'James Carncors',
#  'Thomas Craig',
#  'Robert Rait',
#  'Gerard David',
#  'Ernest Archibald Davidson',
#  'William Brownehill',
#  'J. Sigurjonson',
#  'Jonet Mailvyn',
#  'MSc Criminology',
#  'Escog',
#  'SL Parker',
#  'Samuel Mitchelson',
#  'Boznecho De Ostrow',
#  'Hugh Watt',
#  'Robert Choate Tyron',
#  'Christine Haldane',
#  'Anne Borthwick',
#  'Charles Thelander M.B.',
#  'Dietrich Schulz-Köhn',
#  'Mariota Dicsone',
#  'Alexander Bailzie',
#  'John Milne',
#  'Agnes Barr Auchencloss',
#  'Glendining',
#  'Friedrich Kroning',
#  'Tides',
#  'Laurence MacKenzie - with',
#  'Alexander De',
#  'McEwan Hall - Alan Owen MA - Degree',
#  'Bjoern L. Basberg',
#  'Gurnsey',
#  'J. McWhir',
#  'N. A.',
#  'H45 Hayes',
#  'Alexander Halkerstoun',
#  'Kathleen Bliss',
#  'Garnham',
#  'Lucy Waterhouse',
#  'David Drummond',
#  'Alexander Masoune',
#  'William Bridok',
#  'Schultz',
#  'Cadzow',
#  'Alexander Suvorov',
#  'Jan Hambourg',
#  'Carnforth J.',
#  'John Dog',
#  'John M. Mitchell',
#  'Christian E. G.',
#  'Raster Torbryn',
#  'Cora',
#  'Proficiency Students',
#  'Pontificorum',
#  'Matth',
#  'Henry Cary',
#  'Jersey Cow\n\n',
#  'FR Lillie',
#  'Mitchison',
#  'David Smith Cairns',
#  'Adam Weddale',
#  'Miss Dodds',
#  'Thomas S. Brown',
#  'John McIntyre',
#  'Scotticised English',
#  'Alexander Bauereage',
#  'John Graham Kerr\n\n',
#  'William Schorthous',
#  'Thomas Martyne of Lathoms',
#  'Koteliansky',
#  'Archibald Fergusson',
#  'Boyer',
#  'John Strathauchin',
#  'David Semple',
#  'Thomas Mason',
#  'Otto Peininger',
#  'Mrs A. Kestler',
#  'George Parker\n\n',
#  'George Crawfurd',
#  'Joseph Bell',
#  'B. J. Gradwell\n\n',
#  'Alister\n\nScope',
#  'Centaur',
#  'PGD',
#  'Haveley',
#  'Brevia Antiqua',
#  'James Blayr',
#  'Kynquhereis',
#  'Bonnie Prince',
#  'William Carubris',
#  'Benson',
#  'Gustav Behrens',
#  'Growth Characteristics',
#  'Henry B. Marshall-of-Buchan-Broughton',
#  'John Westualter',
#  'Charlotte Joyce',
#  'Wright',
#  'Harry Kernoff',
#  'Emma Anthony',
#  'Mrs Scott',
#  'Ernest\n\nScope and',
#  'Jean Margaret Bowe',
#  'Victor Gollancz Ltd.',
#  'EY',
#  'George Buchanan',
#  'R. W. Hobbs',
#  'Son Duncan',
#  'Frank Merrick',
#  'Irene Cairns',
#  'James Mudy',
#  'Preston',
#  'Johnston',
#  'L. E. Falk',
#  'Alexander Betoun',
#  'Jonsson Thorkelin',
#  'Mary D Geikie',
#  'James T Hobbs of Maisey',
#  'Zita',
#  'Robert Mure',
#  'Gosewyke',
#  'Andy Tait',
#  'Horses',
#  'Virginia Mandeczewski',
#  'William D Kennedy',
#  'Dean Faculty',
#  'Rosalind Mary Mitchison',
#  'John Greiff',
#  'Eileen Hutton',
#  'James Dalrymple c.1774',
#  "Robert Knox's",
#  'William F\n\nScope',
#  'Mrs Siddous',
#  'Michael Gilbert',
#  'al-Fallahin',
#  'James Wycht',
#  'John Culpar',
#  'Academie Bulgarie des Sciences',
#  'Henry Dundas',
#  'Alex Murchison',
#  'William Laing / Georg',
#  'J. McFadyean',
#  'Achaltetie',
#  'Walter Scottengravings',
#  'Stafford Cripps',
#  'Godfrey Thomson\n\n',
#  'Andrew M. White',
#  'R. I. Murchison',
#  'Sydney M. Glen\n\n',
#  'Moorit',
#  "W. H. Auden'",
#  "Nigel M'Nele",
#  'F. J. Bolton',
#  'Sheila Maureen',
#  'Alphonse Favre',
#  'Tennant',
#  'Johann Wolfgang von Goethe',
#  'Slonimiski',
#  'Francesco Gasperini',
#  'Walter Goodal',
#  'Davina Ferguson',
#  'P.M. Bhargava',
#  'Debussy',
#  "Donald Macpherson Baillie's",
#  'Robyn Williams',
#  'Margaret Storm',
#  'Akman',
#  'John Halliday',
#  'Firbush',
#  'Christabel Harriette',
#  'Arithmetic',
#  'Lambart',
#  'Valda Grieve',
#  'Percy Johnson Marshall',
#  'Phillpotts-Williams',
#  'Attlee',
#  'Elizabeth Looker',
#  'Evesques Heretiques',
#  'Gamgee',
#  'Thomas Suderland',
#  'Donald Patriksoun',
#  'William [Lauder',
#  'William Arnott Fleming',
#  'Gordon D. Rapp',
#  'Peter Henry Buck\n\n',
#  'Edward D Crabb',
#  'M Standfuss',
#  'Lewis Wolpert;Figs',
#  'GermanMarjory Kennedy',
#  'Wee Macgregor - Bengal State Elephant',
#  'Mary\n\nScope and',
#  'John Fourrous',
#  "A. Koestler's",
#  'Crawfurd',
#  'David Rizzio',
#  'Nether Clermiston',
#  "St Patrick's",
#  'William T. Baxter\n\nScope',
#  'Herbert Maxwell',
#  'Hugh McNiele',
#  'William Schewan',
#  'John Greg',
#  'Padagogisches Zentralblatt',
#  'Brian Black',
#  'Patrick Cockburii',
#  'George Orwell',
#  'Greta Busch',
#  'Cotton',
#  'J. Mitford',
#  'Timothy Cagneoli',
#  'Patrick Flokr',
#  'J. Zhu',
#  'H.C.',
#  'James Malloch',
#  'William Mungall',
#  'County Down',
#  'Edinmarnachtie',
#  'Thomas Moulton',
#  'William Hole',
#  'Arthur Dean\n\n',
#  'Arthur KoestlerLusty',
#  'James Matthew BarrieLord',
#  "Peter McIntyre's",
#  'Michel Angelo Gasparini\n\n',
#  'Dorothy',
#  'Deborah Charlesworth;Tape III',
#  'W. B. Wordsworth\n\n',
#  'Irvine',
#  'Percival W. Hulbert',
#  'Lectures V-VII',
#  'C. F.\n\nScope and',
#  'Margaret Emily',
#  'W. S. Library',
#  'Winifred A. Donaldson',
#  'Robert Ellem',
#  'Loch Earn',
#  'St Louis',
#  'Thomas Home',
#  'Walter Bannerman',
#  'William Allan',
#  'Robert Calverley Trevelyan',
#  'Avril Isobel',
#  'Vitaliano Brancati',
#  'Canberra',
#  'Gordon Landon',
#  'W. Howard',
#  'A. Leutzberg',
#  'Burt',
#  'L53 La Croix',
#  'Christina Porter',
#  'Jules\n\nScope and',
#  'Elizabeth Lightbody',
#  'Maize Gluten Feed',
#  'Kherigarh Bull',
#  "St Oran's",
#  'John I. Chalmers',
#  'John Barrington Wain',
#  'John G. Campbell',
#  'James Douglas',
#  'Archibald Hepburn',
#  'Harry',
#  'John Halden',
#  'Elena Young',
#  'Julian Huxley',
#  'Thomas Bernys',
#  'Lwoff',
#  'Rudi Seikin',
#  'H. M. Francis',
#  'Tannahill',
#  'William Hardyng',
#  'Gurjat',
#  'Dorothy Emmet',
#  'Boughton',
#  'J H Hopwood',
#  'George Durie',
#  'C. E.\n\n',
#  'Kohn-Speyer',
#  'James Lyford-Pike',
#  "Tam Dalyell's",
#  'D Collmann',
#  'James Wright',
#  'Patrick Downald',
#  'Winifred Logan Gordon',
#  'C. K. G. Billings',
#  'Arizona Copper',
#  'William John Dundas',
#  'Frederick Thomas Morrison\n\nScope and',
#  'Border',
#  'Thomas Hartley Cromek',
#  'Sophie Weisse',
#  'D. Lloyd George',
#  'Balrowny',
#  'Tswana',
#  'J. Slee',
#  'V. L.\n\n',
#  'Kathleen R. McLaren',
#  'John Grey',
#  'Welsh Boar',
#  'Lady Torfrida Ransford',
#  'Monica Jean\n\n',
#  'Sec',
#  "M. Brown's",
#  'Wurttemberg',
#  'J. O. Halliwell',
#  'Maurice Drummond',
#  'Jake Kugel',
#  'Khilia F. Kushner',
#  'Jollos',
#  'Stockbridge',
#  'Mr Ryrie',
#  'Irene',
#  'David Talbot',
#  'Bodl',
#  'Ron\n\n',
#  'Alexander Ezat',
#  'Malcolm Higges',
#  'Wilkinson',
#  'y-Pant',
#  'Mrs Gilliat',
#  'N. Fiddes Wilson\n\n',
#  'Foullars',
#  "John M'William Dwe",
#  'Robert McDonald',
#  'N2 Neilson',
#  'Gamoose Bull',
#  'Roger of Grendoun',
#  'J.S Martyn\n\n',
#  'Stephen Toulmin',
#  'Jonet Balfour',
#  'Frederick Thomas',
#  'C Jucci',
#  'Walter] Runciman',
#  'John Orr\n\n',
#  'David Low',
#  'Drill Hall',
#  'Kirkman',
#  'John [Colville',
#  'A. M. Mackinnon',
#  'Lily Jackson',
#  'Perry',
#  'Albert Venn',
#  'Custom Revenue',
#  'Harold Salvesen',
#  "Robert Henderson's",
#  'Covenant',
#  'George Edward',
#  'Violet Kennedy-Erskine',
#  'St Andrew St.',
#  'Worm',
#  'Janine',
#  'Ebenezer Henderson',
#  'Yarmouth',
#  'Reedbuck Ram\n\n',
#  'Boman',
#  'Mathew Hamylton',
#  'Modelshi',
#  'Harold\n\n',
#  'Prof Jurasz',
#  'Ramon Blanco',
#  'William Chalmer',
#  'William Logie',
#  'Elizabeth Hunter',
#  'Evelyn Chetwode',
#  "Bulletin de l'Academie Polonaise des Sciences",
#  'John Porteous\n\nScope and',
#  'John Kenyon Mason',
#  'Greig',
#  'James Buchanan',
#  'Kenneth E. Boulding',
#  'Alessandro Scarlatti',
#  'Andrew Mertyne',
#  'Peter Mclaren',
#  'Cavaye',
#  'K6 Keith',
#  'Adeane',
#  'David Livingstone',
#  'Naturforscher Leopoldina',
#  'Merioneth',
#  'John Simpline',
#  'Uri Fr',
#  'Charles de\n\nScope',
#  'Ryegrass',
#  'Library College',
#  'Edward Atkinson Hornel',
#  "David G Kendall's",
#  'James Ogilvy',
#  'Maisons de Bois',
#  'Walter Scott / Kinnoull',
#  'William Malwyn',
#  'Fossil',
#  'Richard Chatto',
#  'Robert Allan',
#  'Duns',
#  'Bogan',
#  "Mrs Cameron'",
#  'John Craigie',
#  'Frederick S. Mackay\n\n',
#  'Shorthorn Dairy Cow',
#  "Charlotte Ledermann's",
#  "Michael M'Crekane",
#  'Maurice Collis',
#  'a Vera Henderson',
#  'Kathleen A. Boyd',
#  'Anthony\n\nScope and',
#  'Fyodor Dostoevsky',
#  'Saxmundham',
#  'Duncan B. Forrester',
#  'CH Hurst',
#  "Thomas Cumpston - Anglus - '",
#  'Joy Elizabeth\n\n',
#  'Threshold',
#  'Charles Esplin / J.',
#  'De Hasteville',
#  'Malcolm McKinnon',
#  'W20 Wilmot',
#  'Harold Nature',
#  "Travels Thro'",
#  'Henry Balnavis',
#  'Nick Barton;Tape III',
#  "Louis Roy'",
#  'Mordington',
#  'Thesaurus Devonico-Carboniferous',
#  'Baldowy',
#  'Forbes',
#  'Clifton',
#  'Monterduffy',
#  'Barbara Jane',
#  'Skeleton Rear View',
#  'Aufbau Reconstructionpp.1-2Sent',
#  'Robert Clark',
#  'Alexander Napier',
#  'Ayrshire Cow',
#  'H.M. Tomlinson',
#  'Hugh Sutherland',
#  'Evelyn Valerie\n\n',
#  'C. P. E. Bach',
#  'Kerry Ram\n\n',
#  'E.F. Gale',
#  'Peter Strang',
#  'Henrico Spelmanno',
#  'Alice Blanche Balfour',
#  'Sr John Scott',
#  'Walton Hall',
#  'Sandy',
#  "Edinburgh Mela '",
#  'Katharine M. Martin',
#  'C16 Caverhill',
#  'Mitcheson',
#  'J.G Gill\n\nTitle',
#  'Jean Fraser',
#  'Rudolf Presber',
#  'William Blaikze',
#  'E. R. Yerbury',
#  'Salve Christian Fredrik Salvesen',
#  'Fyndlaw Robertson',
#  'John Beill',
#  'David Whitehead Ltd',
#  'Mr Ross',
#  'Domini',
#  'J. G. Pulling',
#  'Dalkeith Road, Edinburgh',
#  'Bioprocessing',
#  'Robert of Hagarston',
#  'Karl Parsons',
#  'Henrich Möller',
#  'Johan de Cliddcrowe',
#  'Adam Moscrop',
#  'David Balfour',
#  'Kikuyu Grammar',
#  'Walter R. Spalding',
#  'William Henry Walsh',
#  'Bocklein',
#  'Elizabeth Edith',
#  'David Ogilvy',
#  'JB Hutchinson',
#  'Carl Deis',
#  'James Murcheston',
#  'John Flarity',
#  'Aranyi',
#  'Majesty',
#  'William Braud - Use',
#  'Charles D. Jack',
#  'Kerr',
#  'F. A. E. Crew\n\nScope and Contents',
#  'Joseph Banks',
#  "Blind Harry's",
#  "John M'Henry",
#  'William Hare',
#  'Fra Angelico da Fiesole',
#  'Jakob\n\nScope and',
#  'Daniel Stewarts',
#  'Netherbyer',
#  'Koleda',
#  'Co Ironmongers',
#  'A. Muzzolini',
#  'Thaithong',
#  'Sydenham',
#  'John William Arthur',
#  'RK Callow',
#  'LJ Blacher',
#  'Patrick Hamiltoun',
#  'Townshead Rd',
#  'Ceara Tree',
#  'H. Erskine Hill',
#  'John Strother',
#  'Maxtone Graham',
#  'Berks',
#  'R. M. Young',
#  'James Denney',
#  'Merino',
#  'Etude Particulière de la Théorie de Fisher',
#  'George F Manderson',
#  "John Coleman's",
#  'Holger',
#  'Ceara-Tapping',
#  'R10 Russell',
#  ...]

# %% [markdown]
# Not perfect...some non-person entities labeled such as `Librarian` and `Diploma`.  I'll add labeling person names to the annotation instructions!

# %% [markdown]
# <a id="check-dups"></a>
# ## III. Checking for Duplicate Descriptions

# %%
# descs = PlaintextCorpusReader("../AnnotationData/descriptions_by_fonds_split_with_ann/descriptions_by_fonds_split_with_ann/", ".+\.txt")
# fileids = descs.fileids()
# descs.raw(fileids[0])

# %%
x = descs.raw(fileids[0])
x.split("\n")
# Out:
# ['Identifier: AA4',
#  '',
#  'Title:',
#  'Papers of Rev Prof John McIntyre (1916-2005)',
#  '',
#  'Scope and Contents:',
#  'Sermons and addresses, 1940-1997; personal papers, 1932-2006; lectures, 1946-1990; class notes and lecture notes, 1932-1941; correspondence, 1979-1983; papers relating to the Dean of the Thistle, 1974-1980; newspaper cuttings, 1945-1982; publications and articles, 1929-1987; essays, 1935-1979, audio cassette tapes, 1987 and papers relating to television broadcasts, 1960-1967.See also External Documents (below).',
#  '',
#  'Biographical / Historical:',
#  "John McIntyre (1916-2005) was born in Glasgow, educated at Bathgate Academy and then Edinburgh University where he graduated in philosophy and then in divinity. In 1943 he became the minister of the Ayrshire village of Fenwick before leaving Scotland in 1945 to teach theology at St Andrew's College in the University of Sydney. Rev McIntyre remained in Australia until 1956 when he returned to Scotland to become professor of divinity at New College.",
#  'In 1972, he was asked to be interim Moderator in St Giles Cathedral and in 1982-1983 stood as Moderator of the General Assembly. In 1989 he was awarded the CVO.',
#  '']

# %%
descs_split = []
for fileid in fileids:
    d = descs.raw(fileid).split("\n")
    for section in d:
        if len(section) > 0:
            if "Identifier" not in section and "Title" not in section and "Scope and Contents" not in section and "Biographical / Historical" not in section and "Processing Information" not in section and "No information provided" not in section:
                descs_split += [section]
print(descs_split[0:4])
# Out:
# ['Papers of Rev Prof John McIntyre (1916-2005)', 'Sermons and addresses, 1940-1997; personal papers, 1932-2006; lectures, 1946-1990; class notes and lecture notes, 1932-1941; correspondence, 1979-1983; papers relating to the Dean of the Thistle, 1974-1980; newspaper cuttings, 1945-1982; publications and articles, 1929-1987; essays, 1935-1979, audio cassette tapes, 1987 and papers relating to television broadcasts, 1960-1967.See also External Documents (below).', "John McIntyre (1916-2005) was born in Glasgow, educated at Bathgate Academy and then Edinburgh University where he graduated in philosophy and then in divinity. In 1943 he became the minister of the Ayrshire village of Fenwick before leaving Scotland in 1945 to teach theology at St Andrew's College in the University of Sydney. Rev McIntyre remained in Australia until 1956 when he returned to Scotland to become professor of divinity at New College.", 'In 1972, he was asked to be interim Moderator in St Giles Cathedral and in 1982-1983 stood as Moderator of the General Assembly. In 1989 he was awarded the CVO.']

# %%
len(descs_split)
# Out:
# 93636

# %%
len(set(descs_split))
# Out:
# 82258

# %%
print(len(descs_split)-len(set(descs_split)))
# Out:
# 11378

# %% [markdown]
# It looks like there are 11,378 descriptions that are repeated in the corpus.
